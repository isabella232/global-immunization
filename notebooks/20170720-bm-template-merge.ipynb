# %%
# -*- coding: utf-8 -*-
# %matplotlib inline

import pandas as pd
import numpy as np
import math
import matplotlib as mplstyle
import matplotlib.pyplot as plt
import locale
import arrow
from locale import atof
from dateutil import parser
from datetime import datetime

# %% [markdown]
# ### Imports

# %%
df_countryNames = pd.read_csv('../data/imports/country-names.csv')
df_countryNames[df_countryNames['SOV_A3'] == 'MDV']
# Out:
#      scalerank        featurecla  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  \
# 166          5  Admin-0 map unit        5.0   Maldives    MDV       0.0
#
#      LEVEL               TYPE     ADMIN ADM0_A3   ...     ADM0_A3_WB  \
# 166    2.0  Sovereign country  Maldives     MDV   ...          -99.0
#
#                    CONTINENT REGION_UN      SUBREGION   REGION_WB NAME_LEN  \
# 166  Seven seas (open ocean)      Asia  Southern Asia  South Asia      8.0
#
#      LONG_LEN ABBREV_LEN TINY HOMEPART
# 166       8.0        5.0  2.0      1.0
#
# [1 rows x 65 columns]

# %% [markdown]
# ### Analysis

# %%
list(df_countryNames)
cols = ['ADM0_A3_IS','ISO_A3','ISO_N3','ABBREV','GEOUNIT','NAME','NAME_LONG']
df_condCountryNames = df_countryNames[cols]
df_condCountryNames
# df_condCountryNames[df_condCountryNames['ADM0_A3_US'] == 'MDV']
# list(df_countryNames)
# Out:
#     ADM0_A3_IS ISO_A3  ISO_N3       ABBREV  \
# 0          ABW    ABW     533        Aruba
# 1          ATG    -99     -99         Ant.
# 2          ATG    -99     -99        Barb.
# 3          AFG    AFG       4         Afg.
# 4          AGO    AGO      24         Ang.
# 5          AIA    AIA     660         Ang.
# 6          ALB    ALB       8         Alb.
# 7          ALA    ALA     248        Aland
# 8          AND    AND      20         And.
# 9          ARE    ARE     784       U.A.E.
# 10         ARG    ARG      32         Arg.
# 11         ARM    ARM      51         Arm.
# 12         ASM    ASM      16    Am. Samoa
# 13         ATA    ATA      10         Ant.
# 14         AUS    -99      36      A.C.Is.
# 15         ATF    ATF     260   Fr. S.A.L.
# 16         AUS    AUS      36         Auz.
# 17         AUT    AUT      40        Aust.
# 18         AZE    AZE      31         Aze.
# 19         BEL    -99     -99        Brus.
# 20         BDI    BDI     108         Bur.
# 21         BEN    BEN     204        Benin
# 22         BFA    BFA     854         B.F.
# 23         BEL    -99     -99        Flem.
# 24         BGD    BGD      50        Bang.
# 25         BGR    BGR     100        Bulg.
# 26         BIH    -99     -99         B.D.
# 27         BIH    -99     -99         B.H.
# 28         BHR    BHR      48        Bahr.
# 29         BHS    BHS      44         Bhs.
# ..         ...    ...     ...          ...
# 265        TTO    TTO     780        Tr.T.
# 266        TUN    TUN     788         Tun.
# 267        TUR    TUR     792         Tur.
# 268        TUV    TUV     798         Tuv.
# 269        TWN    TWN     158       Taiwan
# 270        TZA    TZA     834        Tanz.
# 271        TZA    -99     -99         Zan.
# 272        UGA    UGA     800         Uga.
# 273        UKR    UKR     804         Ukr.
# 274        URY    URY     858         Ury.
# 275        USA    USA     840       U.S.A.
# 276        -99    -99     -99     Guantan.
# 277        UZB    UZB     860         Uzb.
# 278        VAT    VAT     336         Vat.
# 279        VCT    VCT     670      St.V.G.
# 280        VEN    VEN     862         Ven.
# 281        VGB    VGB      92   V.I. (Br.)
# 282        VIR    VIR     850  V.I. (U.S.)
# 283        VNM    VNM     704        Viet.
# 284        VUT    VUT     548         Van.
# 285        PSE    -99     275         W.B.
# 286        WLF    WLF     876         Wlf.
# 287        -99    -99     -99        Wales
# 288        WQI    -99     -99     Wake At.
# 289        GBR    -99     -99         Akr.
# 290        WSM    WSM     882        Samoa
# 291        YEM    YEM     887         Yem.
# 292        ZAF    ZAF     710        S.Af.
# 293        ZMB    ZMB     894       Zambia
# 294        ZWE    ZWE     716        Zimb.
#
#                                  GEOUNIT                     NAME  \
# 0                                  Aruba                    Aruba
# 1                                Antigua                  Antigua
# 2                                Barbuda                  Barbuda
# 3                            Afghanistan              Afghanistan
# 4                                 Angola                   Angola
# 5                               Anguilla                 Anguilla
# 6                                Albania                  Albania
# 7                                  Aland                    Aland
# 8                                Andorra                  Andorra
# 9                   United Arab Emirates     United Arab Emirates
# 10                             Argentina                Argentina
# 11                               Armenia                  Armenia
# 12                        American Samoa           American Samoa
# 13                            Antarctica               Antarctica
# 14           Ashmore and Cartier Islands  Ashmore and Cartier Is.
# 15   French Southern and Antarctic Lands   Fr. S. Antarctic Lands
# 16                             Australia                Australia
# 17                               Austria                  Austria
# 18                            Azerbaijan               Azerbaijan
# 19               Brussels Capital Region                 Brussels
# 20                               Burundi                  Burundi
# 21                                 Benin                    Benin
# 22                          Burkina Faso             Burkina Faso
# 23                        Flemish Region                  Flemish
# 24                            Bangladesh               Bangladesh
# 25                              Bulgaria                 Bulgaria
# 26                        Brcko District           Brcko District
# 27                Bosnia and Herzegovina     Fed. of Bos. & Herz.
# 28                               Bahrain                  Bahrain
# 29                           The Bahamas                  Bahamas
# ..                                   ...                      ...
# 265                  Trinidad and Tobago      Trinidad and Tobago
# 266                              Tunisia                  Tunisia
# 267                               Turkey                   Turkey
# 268                               Tuvalu                   Tuvalu
# 269                               Taiwan                   Taiwan
# 270                             Tanzania                 Tanzania
# 271                             Zanzibar                 Zanzibar
# 272                               Uganda                   Uganda
# 273                              Ukraine                  Ukraine
# 274                              Uruguay                  Uruguay
# 275             United States of America            United States
# 276         US Naval Base Guantanamo Bay      USNB Guantanamo Bay
# 277                           Uzbekistan               Uzbekistan
# 278                              Vatican                  Vatican
# 279     Saint Vincent and the Grenadines       St. Vin. and Gren.
# 280                            Venezuela                Venezuela
# 281               British Virgin Islands       British Virgin Is.
# 282         United States Virgin Islands          U.S. Virgin Is.
# 283                              Vietnam                  Vietnam
# 284                              Vanuatu                  Vanuatu
# 285                            West Bank                West Bank
# 286                    Wallis and Futuna    Wallis and Futuna Is.
# 287                                Wales                    Wales
# 288                           Wake Atoll               Wake Atoll
# 289         Akrotiri Sovereign Base Area                 Akrotiri
# 290                                Samoa                    Samoa
# 291                                Yemen                    Yemen
# 292                         South Africa             South Africa
# 293                               Zambia                   Zambia
# 294                             Zimbabwe                 Zimbabwe
#
#                                 NAME_LONG
# 0                                   Aruba
# 1                                 Antigua
# 2                                 Barbuda
# 3                             Afghanistan
# 4                                  Angola
# 5                                Anguilla
# 6                                 Albania
# 7                           Aland Islands
# 8                                 Andorra
# 9                    United Arab Emirates
# 10                              Argentina
# 11                                Armenia
# 12                         American Samoa
# 13                             Antarctica
# 14            Ashmore and Cartier Islands
# 15    French Southern and Antarctic Lands
# 16                              Australia
# 17                                Austria
# 18                             Azerbaijan
# 19                               Brussels
# 20                                Burundi
# 21                                  Benin
# 22                           Burkina Faso
# 23                         Flemish Region
# 24                             Bangladesh
# 25                               Bulgaria
# 26                         Brcko District
# 27   Federation of Bosnia and Herzegovina
# 28                                Bahrain
# 29                                Bahamas
# ..                                    ...
# 265                   Trinidad and Tobago
# 266                               Tunisia
# 267                                Turkey
# 268                                Tuvalu
# 269                                Taiwan
# 270                              Tanzania
# 271                              Zanzibar
# 272                                Uganda
# 273                               Ukraine
# 274                               Uruguay
# 275                         United States
# 276          US Naval Base Guantanamo Bay
# 277                            Uzbekistan
# 278                               Vatican
# 279      Saint Vincent and the Grenadines
# 280                             Venezuela
# 281                British Virgin Islands
# 282          United States Virgin Islands
# 283                               Vietnam
# 284                               Vanuatu
# 285                             West Bank
# 286             Wallis and Futuna Islands
# 287                                 Wales
# 288                            Wake Atoll
# 289                              Akrotiri
# 290                                 Samoa
# 291                                 Yemen
# 292                          South Africa
# 293                                Zambia
# 294                              Zimbabwe
#
# [295 rows x 7 columns]

# %%
df_condCountryNames.to_csv('../data/exports/complete-country-list.csv')

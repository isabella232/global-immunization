# %%
# -*- coding: utf-8 -*-
# %matplotlib inline

import pandas as pd
import numpy as np
import math
import matplotlib as mplstyle
import matplotlib.pyplot as plt
import locale
import arrow
from locale import atof
from dateutil import parser
from datetime import datetime

# %% [markdown]
# ### Functions

# %%
def percentChange(val1, val2):
    val1 = round(val1, 2)
    val2 = round(val2, 2)
    percChange = (val2-val1)/val1
    return round((percChange * 100),2)

# %% [markdown]
# ### Import

# %%
df = pd.read_csv('../data/imports/dtp1.csv')

# %% [markdown]
# ### By Country

# %%
# Drop vaccine column
df_clean = df.drop('vaccine', axis=1)

# %%
# Find percent change
df_clean['percChange'] = np.vectorize(percentChange)(df_clean['1996'],df_clean['2016'])

# %%
# df_clean.sort_values('percChange')
df_under90 = df_clean[df_clean['2016'] < 90]
df_under90.sort_values('country')
# Out:
#                      unicef_region iso3                           country  \
# 0                       South Asia  AFG                       Afghanistan
# 4        Eastern & Southern Africa  AGO                            Angola
# 18           West & Central Africa  BEN                             Benin
# 23       Latin America & Caribbean  BRA                            Brazil
# 32           West & Central Africa  CAF          Central African Republic
# 33           West & Central Africa  TCD                              Chad
# 38           West & Central Africa  COG                             Congo
# 47           West & Central Africa  COD  Democratic Republic of the Congo
# 55           West & Central Africa  GNQ                 Equatorial Guinea
# 58       Eastern & Southern Africa  ETH                          Ethiopia
# 62           West & Central Africa  GAB                             Gabon
# 70           West & Central Africa  GIN                            Guinea
# 73       Latin America & Caribbean  HTI                             Haiti
# 80      Middle East & North Africa  IRQ                              Iraq
# 89             East Asia & Pacific  KIR                          Kiribati
# 92             East Asia & Pacific  LAO  Lao People�s Democratic Republic
# 94      Middle East & North Africa  LBN                           Lebanon
# 100      Eastern & Southern Africa  MDG                        Madagascar
# 101      Eastern & Southern Africa  MWI                            Malawi
# 104          West & Central Africa  MLI                              Mali
# 106            East Asia & Pacific  MHL                  Marshall Islands
# 107          West & Central Africa  MRT                        Mauritania
# 123          West & Central Africa  NER                             Niger
# 124          West & Central Africa  NGA                           Nigeria
# 128                     South Asia  PAK                          Pakistan
# 131            East Asia & Pacific  PNG                  Papua New Guinea
# 134            East Asia & Pacific  PHL                       Philippines
# 147                 Western Europe  SMR                        San Marino
# 158      Eastern & Southern Africa  SOM                           Somalia
# 159      Eastern & Southern Africa  ZAF                      South Africa
# 160      Eastern & Southern Africa  SSD                       South Sudan
# 169     Middle East & North Africa  SYR              Syrian Arab Republic
# 175            East Asia & Pacific  TON                             Tonga
# 181      Eastern & Southern Africa  UGA                            Uganda
# 182  Eastern Europe & Central Asia  UKR                           Ukraine
# 189            East Asia & Pacific  VUT                           Vanuatu
# 192     Middle East & North Africa  YEM                             Yemen
#
#      2016  2015  2014  2013  2012  2011  2010     ...      1988  1987  1986  \
# 0      73    73    73    76    78    78  72.0     ...      60.0  50.0  32.0
# 4      79    77    81    79    83    88  93.0     ...      33.0  31.0  31.0
# 18     86    86    86    86    89    85  87.0     ...      51.0  46.0  36.0
# 23     89    97    98    98    99    99  99.0     ...      80.0  80.0  80.0
# 32     69    69    69    35    69    69  67.0     ...      67.0  46.0  42.0
# 33     60    60    60    58    57    55  55.0     ...      36.0  36.0  31.0
# 38     85    85    95    90    90    90  90.0     ...      89.0  89.0  88.0
# 47     80    82    81    79    81    85  71.0     ...      66.0  63.0  57.0
# 55     40    28    59    49    56    59  59.0     ...      42.0  31.0  21.0
# 58     86    86    86    84    82    80  77.0     ...      39.0  39.0  27.0
# 62     83    87    77    80    86    82  82.0     ...      86.0  76.0  66.0
# 70     65    63    60    76    76    76  86.0     ...      39.0  37.0  37.0
# 73     78    80    72    86    87    88  87.0     ...      72.0  53.0  48.0
# 80     73    73    77    82    87    90  86.0     ...      98.0  98.0  98.0
# 89     82    81    83    95    94    99  97.0     ...      84.0  61.0  62.0
# 92     85    93    94    89    87    83  81.0     ...      40.0  31.0  24.0
# 94     84    84    84    84    84    84  84.0     ...      84.0  71.0  55.0
# 100    84    79    83    80    80    80  78.0     ...      67.0  60.0  55.0
# 101    89    93    97    96    99    98  97.0     ...      94.0  92.0  80.0
# 104    86    82    92    85    81    80  81.0     ...      41.0  28.0  28.0
# 106    87    95    97    97    97    99  99.0     ...      97.0   NaN   NaN
# 107    87    87    88    95    95    91  82.0     ...      62.0  55.0  57.0
# 123    87    85    89    87    87    86  83.0     ...      29.0  27.0  24.0
# 124    64    64    64    58    51    56  60.0     ...      61.0  54.0  46.0
# 128    79    79    79    79    79    84  88.0     ...      63.0  61.0  59.0
# 131    87    83    87    88    85    83  80.0     ...      72.0  69.0  69.0
# 134    87    69    78    93    91    92  81.0     ...      92.0  90.0  86.0
# 147    78    77    82    72    98    90  80.0     ...      99.0  99.0  99.0
# 158    52    52    52    52    52    52  55.0     ...      51.0  50.0  40.0
# 159    78    83    85    81    72    80  80.0     ...      88.0  89.0  88.0
# 160    35    37    49    57    71    79   NaN     ...       NaN   NaN   NaN
# 169    61    62    65    55    68    86  89.0     ...      83.0  71.0  90.0
# 175    83    86    86    86    81    86  86.0     ...      97.0  99.0  91.0
# 181    89    89    89    89    89    91  87.0     ...      67.0  55.0  45.0
# 182    42    59    59    76    76    50  52.0     ...       NaN   NaN   NaN
# 189    75    75    75    75    75    76  76.0     ...      80.0  79.0  56.0
# 192    76    77    82    82    77    79  84.0     ...      61.0  41.0  35.0
#
#      1985  1984  1983  1982  1981  1980  percChange
# 0    37.0  39.0  24.0  24.0   NaN  22.0       30.36
# 4    28.0  28.0  25.0   NaN   NaN   NaN       49.06
# 18   36.0   NaN   NaN   NaN   NaN   NaN        0.00
# 23   86.0  87.0  82.0  79.0  72.0  62.0       18.67
# 32   44.0  40.0  39.0  36.0  32.0  35.0       -4.17
# 33   21.0  21.0  18.0   NaN   NaN   NaN       36.36
# 38   77.0  77.0  74.0  72.0  67.0  67.0       37.10
# 47   62.0  52.0  39.0  40.0  41.0   NaN       95.12
# 55   21.0   NaN   NaN   NaN   NaN   NaN      -57.45
# 58   25.0  22.0  22.0  21.0  21.0   NaN       10.26
# 62   56.0  46.0  36.0   NaN   NaN   NaN        6.41
# 70   37.0  37.0  37.0  37.0   NaN   NaN       -9.72
# 73   42.0  36.0  29.0  35.0  36.0  21.0        4.00
# 80   98.0  81.0  39.0  41.0  35.0  36.0      -17.05
# 89   62.0  41.0  65.0  77.0  54.0  68.0      -10.87
# 92   22.0  24.0  27.0  27.0  27.0   NaN        6.25
# 94   40.0  22.0  22.0  22.0  20.0  17.0      -13.40
# 100  47.0  42.0  47.0  37.0   NaN   NaN       15.07
# 101  78.0  80.0  84.0  84.0  86.0  80.0       -7.29
# 104  28.0   NaN   NaN   NaN   NaN   NaN       11.69
# 106   NaN   NaN   NaN   NaN   NaN   NaN       -5.43
# 107  52.0  45.0  44.0  44.0  41.0   NaN       -2.25
# 123  22.0  24.0  24.0  25.0  25.0   NaN       97.73
# 124  39.0  29.0   NaN   NaN   NaN   NaN       25.49
# 128  55.0  47.0  37.0  24.0  21.0  20.0       27.42
# 131  65.0  59.0  52.0  54.0  57.0  57.0        8.75
# 134  81.0  80.0  78.0  77.0  77.0  72.0        6.10
# 147  99.0  99.0  99.0   NaN   NaN   NaN      -21.21
# 158  46.0  31.0  24.0  24.0  20.0   NaN       15.56
# 159  91.0  91.0  90.0   NaN   NaN   NaN      -13.33
# 160   NaN   NaN   NaN   NaN   NaN   NaN         NaN
# 169  54.0  50.0  45.0  37.0  36.0  35.0      -36.46
# 175  97.0  75.0  84.0  76.0  62.0  65.0      -16.16
# 181  36.0  36.0  36.0  33.0  29.0   NaN       11.25
# 182   NaN   NaN   NaN   NaN   NaN   NaN      -57.58
# 189  55.0  53.0  52.0  46.0   NaN   NaN      -12.79
# 192  33.0  27.0  24.0  22.0  21.0  18.0        5.56
#
# [37 rows x 41 columns]

# %%
df_under90.to_csv('../data/exports/dtp1-df_under90.csv')

# %% [markdown]
# ### By Region

# %%
# Group by region
df_byRegion = df_clean.groupby('unicef_region').mean().reset_index().sort_values('2016',ascending=False)

# %%
# Find percent change
df_byRegion['percChange'] = np.vectorize(percentChange)(df_byRegion['1986'],df_byRegion['2016'])

# %%
# df_byRegion.sort_values('percChange')

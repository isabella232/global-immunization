# %%
# -*- coding: utf-8 -*-
# %matplotlib inline

import pandas as pd
import numpy as np
import math
import matplotlib as mplstyle
import matplotlib.pyplot as plt
import locale
import arrow
from locale import atof
from dateutil import parser
from datetime import datetime

# %% [markdown]
# ### Imports

# %%
df_countryNames = pd.read_csv('../data/imports/country-names.csv')

# %% [markdown]
# ### Analysis

# %%
list(df_countryNames)
cols = ['ADM0_A3','ISO_N3','ABBREV','GEOUNIT','NAME_LONG']
# Out:
# ['scalerank',
#  'featurecla',
#  'LABELRANK',
#  'SOVEREIGNT',
#  'SOV_A3',
#  'ADM0_DIF',
#  'LEVEL',
#  'TYPE',
#  'ADMIN',
#  'ADM0_A3',
#  'GEOU_DIF',
#  'GEOUNIT',
#  'GU_A3',
#  'SU_DIF',
#  'SUBUNIT',
#  'SU_A3',
#  'BRK_DIFF',
#  'NAME',
#  'NAME_LONG',
#  'BRK_A3',
#  'BRK_NAME',
#  'BRK_GROUP',
#  'ABBREV',
#  'POSTAL',
#  'FORMAL_EN',
#  'FORMAL_FR',
#  'NOTE_ADM0',
#  'NOTE_BRK',
#  'NAME_SORT',
#  'NAME_ALT',
#  'MAPCOLOR7',
#  'MAPCOLOR8',
#  'MAPCOLOR9',
#  'MAPCOLOR13',
#  'POP_EST',
#  'GDP_MD_EST',
#  'POP_YEAR',
#  'LASTCENSUS',
#  'GDP_YEAR',
#  'ECONOMY',
#  'INCOME_GRP',
#  'WIKIPEDIA',
#  'FIPS_10_',
#  'ISO_A2',
#  'ISO_A3',
#  'ISO_N3',
#  'UN_A3',
#  'WB_A2',
#  'WB_A3',
#  'WOE_ID',
#  'WOE_ID_EH',
#  'WOE_NOTE',
#  'ADM0_A3_IS',
#  'ADM0_A3_US',
#  'ADM0_A3_UN',
#  'ADM0_A3_WB',
#  'CONTINENT',
#  'REGION_UN',
#  'SUBREGION',
#  'REGION_WB',
#  'NAME_LEN',
#  'LONG_LEN',
#  'ABBREV_LEN',
#  'TINY',
#  'HOMEPART']

# %%
df_countryNames
# Out:
#      scalerank        featurecla  LABELRANK                        SOVEREIGNT  \
# 0            3  Admin-0 map unit        5.0                       Netherlands
# 1            3  Admin-0 map unit        8.0               Antigua and Barbuda
# 2            3  Admin-0 map unit        8.0               Antigua and Barbuda
# 3            0  Admin-0 map unit        3.0                       Afghanistan
# 4            0  Admin-0 map unit        3.0                            Angola
# 5            3  Admin-0 map unit        6.0                    United Kingdom
# 6            0  Admin-0 map unit        6.0                           Albania
# 7            3  Admin-0 map unit        6.0                           Finland
# 8            0  Admin-0 map unit        6.0                           Andorra
# 9            0  Admin-0 map unit        4.0              United Arab Emirates
# 10           0  Admin-0 map unit        2.0                         Argentina
# 11           0  Admin-0 map unit        6.0                           Armenia
# 12           5  Admin-0 map unit        4.0          United States of America
# 13           0  Admin-0 map unit        4.0                        Antarctica
# 14           6  Admin-0 map unit        5.0                         Australia
# 15           3  Admin-0 map unit        6.0                            France
# 16           0  Admin-0 map unit        2.0                         Australia
# 17           0  Admin-0 map unit        4.0                           Austria
# 18           0  Admin-0 map unit        5.0                        Azerbaijan
# 19           0  Admin-0 map unit        9.0                           Belgium
# 20           0  Admin-0 map unit        6.0                           Burundi
# 21           0  Admin-0 map unit        5.0                             Benin
# 22           0  Admin-0 map unit        3.0                      Burkina Faso
# 23           0  Admin-0 map unit        9.0                           Belgium
# 24           0  Admin-0 map unit        3.0                        Bangladesh
# 25           0  Admin-0 map unit        4.0                          Bulgaria
# 26           0  Admin-0 map unit        8.0            Bosnia and Herzegovina
# 27           0  Admin-0 map unit        8.0            Bosnia and Herzegovina
# 28           5  Admin-0 map unit        4.0                           Bahrain
# 29           3  Admin-0 map unit        4.0                       The Bahamas
# ..         ...               ...        ...                               ...
# 265          3  Admin-0 map unit        5.0               Trinidad and Tobago
# 266          0  Admin-0 map unit        3.0                           Tunisia
# 267          0  Admin-0 map unit        2.0                            Turkey
# 268          5  Admin-0 map unit        6.0                            Tuvalu
# 269          0  Admin-0 map unit        3.0                            Taiwan
# 270          0  Admin-0 map unit        3.0       United Republic of Tanzania
# 271          3  Admin-0 map unit        7.0       United Republic of Tanzania
# 272          0  Admin-0 map unit        3.0                            Uganda
# 273          0  Admin-0 map unit        3.0                           Ukraine
# 274          0  Admin-0 map unit        4.0                           Uruguay
# 275          0  Admin-0 map unit        2.0          United States of America
# 276          0  Admin-0 map unit       10.0                              Cuba
# 277          0  Admin-0 map unit        3.0                        Uzbekistan
# 278          0  Admin-0 map unit        6.0                           Vatican
# 279          3  Admin-0 map unit        6.0  Saint Vincent and the Grenadines
# 280          0  Admin-0 map unit        3.0                         Venezuela
# 281          3  Admin-0 map unit        6.0                    United Kingdom
# 282          3  Admin-0 map unit        6.0          United States of America
# 283          0  Admin-0 map unit        2.0                           Vietnam
# 284          1  Admin-0 map unit        4.0                           Vanuatu
# 285          0  Admin-0 map unit        6.0                            Israel
# 286          5  Admin-0 map unit        4.0                            France
# 287          0  Admin-0 map unit        5.0                    United Kingdom
# 288          6  Admin-0 map unit        6.0          United States of America
# 289          3  Admin-0 map unit        3.0                    United Kingdom
# 290          3  Admin-0 map unit        4.0                             Samoa
# 291          0  Admin-0 map unit        3.0                             Yemen
# 292          0  Admin-0 map unit        2.0                      South Africa
# 293          0  Admin-0 map unit        3.0                            Zambia
# 294          0  Admin-0 map unit        3.0                          Zimbabwe
#
#     SOV_A3  ADM0_DIF  LEVEL               TYPE  \
# 0      NL1       1.0    2.0            Country
# 1      ATG       0.0    3.0           Geo unit
# 2      ATG       0.0    3.0           Geo unit
# 3      AFG       0.0    2.0  Sovereign country
# 4      AGO       0.0    2.0  Sovereign country
# 5      GB1       1.0    2.0         Dependency
# 6      ALB       0.0    2.0  Sovereign country
# 7      FI1       1.0    2.0            Country
# 8      AND       0.0    2.0  Sovereign country
# 9      ARE       0.0    2.0  Sovereign country
# 10     ARG       0.0    2.0  Sovereign country
# 11     ARM       0.0    2.0  Sovereign country
# 12     US1       1.0    2.0         Dependency
# 13     ATA       0.0    2.0      Indeterminate
# 14     AU1       1.0    2.0         Dependency
# 15     FR1       1.0    2.0         Dependency
# 16     AU1       1.0    2.0            Country
# 17     AUT       0.0    2.0  Sovereign country
# 18     AZE       0.0    2.0  Sovereign country
# 19     BEL       0.0    3.0           Geo unit
# 20     BDI       0.0    2.0  Sovereign country
# 21     BEN       0.0    2.0  Sovereign country
# 22     BFA       0.0    2.0  Sovereign country
# 23     BEL       0.0    3.0           Geo unit
# 24     BGD       0.0    2.0  Sovereign country
# 25     BGR       0.0    2.0  Sovereign country
# 26     BIH       0.0    3.0           Geo unit
# 27     BIH       0.0    3.0           Geo unit
# 28     BHR       0.0    2.0  Sovereign country
# 29     BHS       0.0    2.0  Sovereign country
# ..     ...       ...    ...                ...
# 265    TTO       0.0    2.0  Sovereign country
# 266    TUN       0.0    2.0  Sovereign country
# 267    TUR       0.0    2.0  Sovereign country
# 268    TUV       0.0    2.0  Sovereign country
# 269    TWN       0.0    2.0  Sovereign country
# 270    TZA       0.0    2.0  Sovereign country
# 271    TZA       0.0    3.0           Geo unit
# 272    UGA       0.0    2.0  Sovereign country
# 273    UKR       0.0    2.0  Sovereign country
# 274    URY       0.0    2.0  Sovereign country
# 275    US1       1.0    2.0            Country
# 276    CUB       1.0    2.0              Lease
# 277    UZB       0.0    2.0  Sovereign country
# 278    VAT       0.0    2.0  Sovereign country
# 279    VCT       0.0    2.0  Sovereign country
# 280    VEN       0.0    2.0  Sovereign country
# 281    GB1       1.0    2.0         Dependency
# 282    US1       1.0    2.0         Dependency
# 283    VNM       0.0    2.0  Sovereign country
# 284    VUT       0.0    2.0  Sovereign country
# 285    IS1       1.0    3.0           Geo unit
# 286    FR1       1.0    2.0         Dependency
# 287    GB1       1.0    3.0           Geo unit
# 288    US1       1.0    3.0           Geo unit
# 289    GB1       1.0    2.0         Dependency
# 290    WSM       0.0    2.0  Sovereign country
# 291    YEM       0.0    2.0  Sovereign country
# 292    ZAF       0.0    2.0  Sovereign country
# 293    ZMB       0.0    2.0  Sovereign country
# 294    ZWE       0.0    2.0  Sovereign country
#
#                                     ADMIN ADM0_A3   ...     ADM0_A3_WB  \
# 0                                   Aruba     ABW   ...          -99.0
# 1                     Antigua and Barbuda     ATG   ...          -99.0
# 2                     Antigua and Barbuda     ATG   ...          -99.0
# 3                             Afghanistan     AFG   ...          -99.0
# 4                                  Angola     AGO   ...          -99.0
# 5                                Anguilla     AIA   ...          -99.0
# 6                                 Albania     ALB   ...          -99.0
# 7                                   Aland     ALD   ...          -99.0
# 8                                 Andorra     AND   ...          -99.0
# 9                    United Arab Emirates     ARE   ...          -99.0
# 10                              Argentina     ARG   ...          -99.0
# 11                                Armenia     ARM   ...          -99.0
# 12                         American Samoa     ASM   ...          -99.0
# 13                             Antarctica     ATA   ...          -99.0
# 14            Ashmore and Cartier Islands     ATC   ...          -99.0
# 15    French Southern and Antarctic Lands     ATF   ...          -99.0
# 16                              Australia     AUS   ...          -99.0
# 17                                Austria     AUT   ...          -99.0
# 18                             Azerbaijan     AZE   ...          -99.0
# 19                                Belgium     BEL   ...          -99.0
# 20                                Burundi     BDI   ...          -99.0
# 21                                  Benin     BEN   ...          -99.0
# 22                           Burkina Faso     BFA   ...          -99.0
# 23                                Belgium     BEL   ...          -99.0
# 24                             Bangladesh     BGD   ...          -99.0
# 25                               Bulgaria     BGR   ...          -99.0
# 26                 Bosnia and Herzegovina     BIH   ...          -99.0
# 27                 Bosnia and Herzegovina     BIH   ...          -99.0
# 28                                Bahrain     BHR   ...          -99.0
# 29                            The Bahamas     BHS   ...          -99.0
# ..                                    ...     ...   ...            ...
# 265                   Trinidad and Tobago     TTO   ...          -99.0
# 266                               Tunisia     TUN   ...          -99.0
# 267                                Turkey     TUR   ...          -99.0
# 268                                Tuvalu     TUV   ...          -99.0
# 269                                Taiwan     TWN   ...          -99.0
# 270           United Republic of Tanzania     TZA   ...          -99.0
# 271           United Republic of Tanzania     TZA   ...          -99.0
# 272                                Uganda     UGA   ...          -99.0
# 273                               Ukraine     UKR   ...          -99.0
# 274                               Uruguay     URY   ...          -99.0
# 275              United States of America     USA   ...          -99.0
# 276          US Naval Base Guantanamo Bay     USG   ...          -99.0
# 277                            Uzbekistan     UZB   ...          -99.0
# 278                               Vatican     VAT   ...          -99.0
# 279      Saint Vincent and the Grenadines     VCT   ...          -99.0
# 280                             Venezuela     VEN   ...          -99.0
# 281                British Virgin Islands     VGB   ...          -99.0
# 282          United States Virgin Islands     VIR   ...          -99.0
# 283                               Vietnam     VNM   ...          -99.0
# 284                               Vanuatu     VUT   ...          -99.0
# 285                             Palestine     PSX   ...          -99.0
# 286                     Wallis and Futuna     WLF   ...          -99.0
# 287                        United Kingdom     GBR   ...          -99.0
# 288  United States Minor Outlying Islands     UMI   ...          -99.0
# 289          Akrotiri Sovereign Base Area     WSB   ...          -99.0
# 290                                 Samoa     WSM   ...          -99.0
# 291                                 Yemen     YEM   ...          -99.0
# 292                          South Africa     ZAF   ...          -99.0
# 293                                Zambia     ZMB   ...          -99.0
# 294                              Zimbabwe     ZWE   ...          -99.0
#
#                    CONTINENT                REGION_UN  \
# 0              North America                 Americas
# 1              North America                 Americas
# 2              North America                 Americas
# 3                       Asia                     Asia
# 4                     Africa                   Africa
# 5              North America                 Americas
# 6                     Europe                   Europe
# 7                     Europe                   Europe
# 8                     Europe                   Europe
# 9                       Asia                     Asia
# 10             South America                 Americas
# 11                      Asia                     Asia
# 12                   Oceania                  Oceania
# 13                Antarctica               Antarctica
# 14                   Oceania                  Oceania
# 15   Seven seas (open ocean)  Seven seas (open ocean)
# 16                   Oceania                  Oceania
# 17                    Europe                   Europe
# 18                      Asia                     Asia
# 19                    Europe                   Europe
# 20                    Africa                   Africa
# 21                    Africa                   Africa
# 22                    Africa                   Africa
# 23                    Europe                   Europe
# 24                      Asia                     Asia
# 25                    Europe                   Europe
# 26                    Europe                   Europe
# 27                    Europe                   Europe
# 28                      Asia                     Asia
# 29             North America                 Americas
# ..                       ...                      ...
# 265            North America                 Americas
# 266                   Africa                   Africa
# 267                     Asia                     Asia
# 268                  Oceania                  Oceania
# 269                     Asia                     Asia
# 270                   Africa                   Africa
# 271                   Africa                   Africa
# 272                   Africa                   Africa
# 273                   Europe                   Europe
# 274            South America                 Americas
# 275            North America                 Americas
# 276            North America                 Americas
# 277                     Asia                     Asia
# 278                   Europe                   Europe
# 279            North America                 Americas
# 280            South America                 Americas
# 281            North America                 Americas
# 282            North America                 Americas
# 283                     Asia                     Asia
# 284                  Oceania                  Oceania
# 285                     Asia                     Asia
# 286                  Oceania                  Oceania
# 287                   Europe                   Europe
# 288                  Oceania                  Oceania
# 289                     Asia                     Asia
# 290                  Oceania                  Oceania
# 291                     Asia                     Asia
# 292                   Africa                   Africa
# 293                   Africa                   Africa
# 294                   Africa                   Africa
#
#                      SUBREGION                   REGION_WB NAME_LEN  LONG_LEN  \
# 0                    Caribbean   Latin America & Caribbean      5.0       5.0
# 1                    Caribbean   Latin America & Caribbean      7.0       7.0
# 2                    Caribbean   Latin America & Caribbean      7.0       7.0
# 3                Southern Asia                  South Asia     11.0      11.0
# 4                Middle Africa          Sub-Saharan Africa      6.0       6.0
# 5                    Caribbean   Latin America & Caribbean      8.0       8.0
# 6              Southern Europe       Europe & Central Asia      7.0       7.0
# 7              Northern Europe       Europe & Central Asia      5.0      13.0
# 8              Southern Europe       Europe & Central Asia      7.0       7.0
# 9                 Western Asia  Middle East & North Africa     20.0      20.0
# 10               South America   Latin America & Caribbean      9.0       9.0
# 11                Western Asia       Europe & Central Asia      7.0       7.0
# 12                   Polynesia         East Asia & Pacific     14.0      14.0
# 13                  Antarctica                  Antarctica     10.0      10.0
# 14   Australia and New Zealand         East Asia & Pacific     23.0      27.0
# 15     Seven seas (open ocean)          Sub-Saharan Africa     22.0      35.0
# 16   Australia and New Zealand         East Asia & Pacific      9.0       9.0
# 17              Western Europe       Europe & Central Asia      7.0       7.0
# 18                Western Asia       Europe & Central Asia     10.0      10.0
# 19              Western Europe       Europe & Central Asia      8.0       8.0
# 20              Eastern Africa          Sub-Saharan Africa      7.0       7.0
# 21              Western Africa          Sub-Saharan Africa      5.0       5.0
# 22              Western Africa          Sub-Saharan Africa     12.0      12.0
# 23              Western Europe       Europe & Central Asia      7.0      14.0
# 24               Southern Asia                  South Asia     10.0      10.0
# 25              Eastern Europe       Europe & Central Asia      8.0       8.0
# 26             Southern Europe       Europe & Central Asia     14.0      14.0
# 27             Southern Europe       Europe & Central Asia     20.0      36.0
# 28                Western Asia  Middle East & North Africa      7.0       7.0
# 29                   Caribbean   Latin America & Caribbean      7.0       7.0
# ..                         ...                         ...      ...       ...
# 265                  Caribbean   Latin America & Caribbean     19.0      19.0
# 266            Northern Africa  Middle East & North Africa      7.0       7.0
# 267               Western Asia       Europe & Central Asia      6.0       6.0
# 268                  Polynesia         East Asia & Pacific      6.0       6.0
# 269               Eastern Asia         East Asia & Pacific      6.0       6.0
# 270             Eastern Africa          Sub-Saharan Africa      8.0       8.0
# 271             Eastern Africa          Sub-Saharan Africa      8.0       8.0
# 272             Eastern Africa          Sub-Saharan Africa      6.0       6.0
# 273             Eastern Europe       Europe & Central Asia      7.0       7.0
# 274              South America   Latin America & Caribbean      7.0       7.0
# 275           Northern America               North America     13.0      13.0
# 276                  Caribbean   Latin America & Caribbean     19.0      28.0
# 277               Central Asia       Europe & Central Asia     10.0      10.0
# 278            Southern Europe       Europe & Central Asia      7.0       7.0
# 279                  Caribbean   Latin America & Caribbean     18.0      32.0
# 280              South America   Latin America & Caribbean      9.0       9.0
# 281                  Caribbean   Latin America & Caribbean     18.0      22.0
# 282                  Caribbean   Latin America & Caribbean     15.0      28.0
# 283         South-Eastern Asia         East Asia & Pacific      7.0       7.0
# 284                  Melanesia         East Asia & Pacific      7.0       7.0
# 285               Western Asia  Middle East & North Africa      9.0       9.0
# 286                  Polynesia         East Asia & Pacific     21.0      25.0
# 287            Northern Europe       Europe & Central Asia      5.0       5.0
# 288                 Micronesia         East Asia & Pacific     10.0      10.0
# 289               Western Asia       Europe & Central Asia      8.0       8.0
# 290                  Polynesia         East Asia & Pacific      5.0       5.0
# 291               Western Asia  Middle East & North Africa      5.0       5.0
# 292            Southern Africa          Sub-Saharan Africa     12.0      12.0
# 293             Eastern Africa          Sub-Saharan Africa      6.0       6.0
# 294             Eastern Africa          Sub-Saharan Africa      8.0       8.0
#
#     ABBREV_LEN  TINY HOMEPART
# 0          5.0   4.0    -99.0
# 1          4.0 -99.0    -99.0
# 2          5.0 -99.0    -99.0
# 3          4.0 -99.0      1.0
# 4          4.0 -99.0      1.0
# 5          4.0 -99.0    -99.0
# 6          4.0 -99.0      1.0
# 7          5.0   5.0    -99.0
# 8          4.0   5.0      1.0
# 9          6.0 -99.0      1.0
# 10         4.0 -99.0      1.0
# 11         4.0 -99.0      1.0
# 12         9.0   3.0    -99.0
# 13         4.0 -99.0      1.0
# 14         7.0 -99.0    -99.0
# 15        10.0   2.0    -99.0
# 16         4.0 -99.0      1.0
# 17         5.0 -99.0      1.0
# 18         4.0 -99.0      1.0
# 19         5.0 -99.0    -99.0
# 20         4.0 -99.0      1.0
# 21         5.0 -99.0      1.0
# 22         4.0 -99.0      1.0
# 23         5.0 -99.0    -99.0
# 24         5.0 -99.0      1.0
# 25         5.0 -99.0      1.0
# 26         4.0 -99.0    -99.0
# 27         4.0 -99.0    -99.0
# 28         5.0   2.0      1.0
# 29         4.0 -99.0      1.0
# ..         ...   ...      ...
# 265        5.0   2.0      1.0
# 266        4.0 -99.0      1.0
# 267        4.0 -99.0      1.0
# 268        4.0   5.0      1.0
# 269        6.0 -99.0      1.0
# 270        5.0 -99.0      1.0
# 271        4.0 -99.0    -99.0
# 272        4.0 -99.0      1.0
# 273        4.0 -99.0      1.0
# 274        4.0 -99.0      1.0
# 275        6.0 -99.0      1.0
# 276        8.0 -99.0    -99.0
# 277        4.0   5.0      1.0
# 278        4.0   4.0      1.0
# 279        7.0 -99.0      1.0
# 280        4.0 -99.0      1.0
# 281       10.0   3.0    -99.0
# 282       11.0   3.0    -99.0
# 283        5.0   2.0      1.0
# 284        4.0   2.0      1.0
# 285        4.0 -99.0    -99.0
# 286        4.0   3.0    -99.0
# 287        5.0 -99.0      1.0
# 288        8.0 -99.0    -99.0
# 289        4.0 -99.0    -99.0
# 290        5.0 -99.0      1.0
# 291        4.0 -99.0      1.0
# 292        5.0 -99.0      1.0
# 293        6.0 -99.0      1.0
# 294        5.0 -99.0      1.0
#
# [295 rows x 65 columns]
